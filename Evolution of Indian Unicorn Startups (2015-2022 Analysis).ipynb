# %% [markdown]
# # A Glimpse into the Evolution: Indian Unicorn Startups
#
# In the vibrant landscape of India's startup world, a remarkable story is unfolding. A total of 101 innovative companies have achieved the prestigious status of unicorns, symbolizing a remarkable surge in entrepreneurship and technology. These unicorns come from various fields, with Edtech leading the way, representing a diverse array of ideas ready to reshape entire industries.
#
# When we delve into their worth, these startups began their journey with an average starting valuation of 1.4 Billion Dollars. Their growth has been nothing short of spectacular, now averaging a valuation of 3.4 Billion Dollars. This progress highlights their potential to bring about significant change. Their journey to becoming unicorns has caught the attention of noteworthy investors who believe in their vision for the future.
#
# These startups are not just businesses; they signify a major shift in India's economic landscape. Visionary investors like Tiger Global, Sequoia Capital India, and Steadview Capital have recognized their potential. As these startups navigate growth and sustainability, they shine as symbols of innovation, job creation, and progress. They're writing an important chapter in India's journey of entrepreneurship.
#
# Born between 2015 and 2022, these startups capture the spirit of our times, playing a vital role in India's journey toward economic advancement.
#
# With profound insights at hand, I am poised to undertake a comprehensive analysis, enriched by insightful graphical representations, to offer a crystalline view of these dynamic trends.
# ![Image](Andhra-Pradesh-Innovation-and-Startup-Policy.jpg)

# %%
# Importing important libraries

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import re
# %matplotlib inline

# %%
data=pd.read_csv('Indian Unicorn startups 2023 updated.csv')
data
# Out:
#      No.             Company                                  Sector  \
# 0      1              InMobi                     Adtech - Mobile Ads
# 1      2           Flipkart^                              E-Commerce
# 2      3            Mu Sigma                        SaaS - Analytics
# 3      4           Snapdeal*                              E-Commerce
# 4      5              PayTM^             Fintech - Payments & Wallet
# ..   ...                 ...                                     ...
# 97    98             Purplle  E-Commerce - Personal Care & Cosmetics
# 98    99         Leadsquared                              SaaS - CRM
# 99   100             OneCard                  Fintech - Credit Cards
# 100  101          Shiprocket         Aggregator - Logistics Services
# 101  102  Molbio Diagnostics                Healthtech - Diagnostics
#
#      Entry Valuation^^ ($B)  Valuation ($B)   Entry             Location  \
# ...

# %%
data.describe()
# Out:
#               No.  Entry Valuation^^ ($B)  Valuation ($B)
# count  102.000000              102.000000      102.000000
# mean    51.500000                1.547549        3.398020
# std     29.588849                1.138013        4.710657
# min      1.000000                1.000000        0.568000
# 25%     26.250000                1.000000        1.200000
# 50%     51.500000                1.200000        1.850000
# 75%     76.750000                1.582500        3.475000
# max    102.000000               10.000000       37.600000

# %% [markdown]
# # Number of unicorn startups each year

# %%
Sector_counts = data['Sector'].value_counts()
Sector_counts
# Out:
# Edtech                                      5
# Marketplace - Used Cars                     4
# E-Commerce                                  4
# Logistics Services                          4
# Gaming                                      3
#                                            ..
# Fintech - Payments & Credit Card Rewards    1
# E-Commerce - Online Pharmacy                1
# Fintech - Brokerage & Mutual Funds          1
# Social Media                                1
# Healthtech - Diagnostics                    1
# Name: Sector, Length: 75, dtype: int64

# %% [markdown]
# # Average Entry Valuation of unicorn startup

# %%
avg_entry_val = data['Entry Valuation^^ ($B)'].mean()
print('Average Entry Valuation: $', avg_entry_val)
# Out:
# Average Entry Valuation: $ 1.5475490196078432

# %% [markdown]
# # Average Valuation of unicorn startup

# %%
Avg_Val = data['Valuation ($B)'].mean()
print("Average Valuation: $", Avg_Val)
# Out:
# Average Valuation: $ 3.398019607843137

# %%
# Check the data types of columns
data.dtypes
# Out:
# No.                         int64
# Company                    object
# Sector                     object
# Entry Valuation^^ ($B)    float64
# Valuation ($B)            float64
# Entry                      object
# Location                   object
# Select Investors           object
# dtype: object

# %% [markdown]
# # Number of unique location

# %%
unique_Location = data['Location'].nunique()
print('Number of Unique Location',unique_Location)
# Out:
# Number of Unique Location 27

# %% [markdown]
# # Top 10 unicorn sectors

# %%
top_10_Sectors = data['Sector'].value_counts().sort_values(ascending=False).head(10)
top_10_Sectors
# Out:
# Edtech                     5
# E-Commerce                 4
# Logistics Services         4
# Marketplace - Used Cars    4
# Gaming                     3
# E-Commerce - Groceries     2
# SaaS - Analytics           2
# SaaS - CRM                 2
# Cryptocurrency Exchange    2
# D2C - Personal Care        2
# Name: Sector, dtype: int64

# %% [markdown]
# # Graphical Representation of top sectors with the most unicorn startups

# %%
plt.figure(figsize=(25,15))
plt.xlabel('Sector', fontsize = 16)
plt.ylabel('Count', fontsize = 16)
plt.title('top sectors with the most unicorn startups', fontsize = 22)
plt.xticks(rotation=45,fontsize =12)
sns.barplot(top_10_Sectors.index,top_10_Sectors.values)
# Out:
# C:\Users\DELL\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:title={'center':'top sectors with the most unicorn startups'}, xlabel='Sector', ylabel='Count'>

# %% [markdown]
# # Top 10 unicorn startups with the highest valuations

# %%
top_valued_startups = data.nlargest(10, 'Valuation ($B)')
print(top_valued_startups[['Company', 'Valuation ($B)']])
# Out:
#       Company  Valuation ($B)
# 1   Flipkart^            37.6
# 10      BYJUS            22.0
# 4      PayTM^            16.0
# 33   PhonePe^            12.0
# 12     Swiggy            10.7
# 85    Polygon            10.0
# 15  OYO Rooms             9.6
# 21    Dream11             8.0
# 31   RazorPay             7.5
# 5    Ola Cabs             7.3

# %% [markdown]
# # Graphical Representation of top 10 unicorn startups with the highest Valuations

# %%
plt.figure(figsize=(25,15))
plt.xlabel('Company', fontsize = 16)
plt.ylabel('Valuation ($B)', fontsize = 16)
plt.title('top 10 unicorn startups with the highest Valuations', fontsize = 22)
plt.xticks(rotation=45,fontsize =12)
sns.barplot(x='Company',y='Valuation ($B)',data=top_valued_startups)
plt.show()

# %% [markdown]
# # Top 5 sectors with the highest total valuations

# %%
top_5_valued_sectors = data.groupby('Sector')['Valuation ($B)'].sum().nlargest(5)
top_5_valued_sectors
# Out:
# Sector
# E-Commerce                     44.1
# Edtech                         28.6
# Foodtech                       16.1
# Fintech - Payments & Wallet    16.0
# Fintech - Payments             14.8
# Name: Valuation ($B), dtype: float64

# %% [markdown]
# # Distribution of most valued unicorn startups across sectors by Percentage

# %%
plt.figure(figsize=(8,6))
top_5_valued_sectors.plot(kind = 'pie', autopct='%1.1f%%')
plt.title('Distribution of Most Valued Unicorn Startups Across Sectors')
plt.ylabel('')
plt.show()

# %% [markdown]
# # Total number of startups in each location

# %%
Cities = data['Location'].value_counts().head(10)
Cities
# Out:
# Bangalore                  34
# Gurgaon                    14
# Mumbai                     12
# Delhi                       7
# Pune                        4
# Noida                       4
# Bangalore/San Francisco     3
# Bangalore/Singapore         3
# Jaipur                      2
# Chennai                     2
# Name: Location, dtype: int64

# %% [markdown]
# # Graphical Representation of top 5 locations with the most unicorn startups

# %%
plt.figure(figsize=(20,10))
plt.title('Number of Unicorn in each City',fontsize=29)
plt.ylabel('Cities',fontsize=25)
plt.xlabel('Count',fontsize=25)
sns.barplot(Cities.values,Cities.index,palette='hot')
plt.show()
# Out:
# C:\Users\DELL\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
data.head()
# Out:
#    No.    Company                       Sector  Entry Valuation^^ ($B)  \
# 0    1     InMobi          Adtech - Mobile Ads                     1.0
# 1    2  Flipkart^                   E-Commerce                     1.0
# 2    3   Mu Sigma             SaaS - Analytics                     1.0
# 3    4  Snapdeal*                   E-Commerce                     1.8
# 4    5     PayTM^  Fintech - Payments & Wallet                     1.7
#
#    Valuation ($B)   Entry             Location  \
# 0             1.0  Sep-11  Bangalore/Singapore
# 1            37.6  Feb-12  Bangalore/Singapore
# 2             1.5  Feb-13    Bangalore/Chicago
# 3             2.4  Oct-14                Delhi
# 4            16.0  Feb-15                Noida
#
#                                     Select Investors
# 0                  KPCB, Sherpalo Ventures, SoftBank
# 1    Accel, Tiger Global, Naspers, SoftBank, Tencent
# 2           Accel, Sequoia Capital, General Atlantic
# ...

# %% [markdown]
# # Total number of startups in each entry year

# %%
unicorns_per_year = data['Entry'].value_counts().sort_index()
unicorns_per_year
# Out:
# Apr-15    1
# Apr-18    1
# Apr-19    1
# Apr-21    8
# Aug-16    1
# Aug-21    7
# Aug-22    1
# Dec-20    4
# Dec-21    3
# Feb-12    1
# Feb-13    1
# Feb-15    1
# Feb-19    1
# Feb-21    2
# Feb-22    6
# Jan-16    1
# Jan-18    1
# Jan-19    1
# Jan-20    1
# Jan-21    1
# Jan-22    4
# Jul-18    1
# Jul-19    3
# Jul-21    3
# Jul-22    1
# Jun-18    2
# Jun-19    1
# Jun-20    1
# Jun-21    1
# Jun-22    3
# Mar-15    1
# Mar-19    1
# Mar-20    1
# Mar-21    2
# Mar-22    4
# May-21    2
# May-22    1
# Nov-18    1
# Nov-20    1
# Nov-21    7
# Oct-14    1
# Oct-20    1
# Oct-21    5
# Sep-11    1
# Sep-15    1
# Sep-18    2
# Sep-19    1
# Sep-20    1
# Sep-21    3
# Sep-22    1
# Name: Entry, dtype: int64

# %% [markdown]
# # Bar chart for total number of startups in each entry year

# %%
plt.plot(figsize=(30,10))
unicorns_per_year.plot(kind='bar', color='Blue')
plt.title('Total Number of Startups in Each Entry Year')
plt.xlabel('Entry Year')
plt.ylabel('Number of Startups')
plt.xticks(rotation=45)
plt.show()

# %%
data.head()
# Out:
#    No.    Company                       Sector  Entry Valuation^^ ($B)  \
# 0    1     InMobi          Adtech - Mobile Ads                     1.0
# 1    2  Flipkart^                   E-Commerce                     1.0
# 2    3   Mu Sigma             SaaS - Analytics                     1.0
# 3    4  Snapdeal*                   E-Commerce                     1.8
# 4    5     PayTM^  Fintech - Payments & Wallet                     1.7
#
#    Valuation ($B)   Entry             Location  \
# 0             1.0  Sep-11  Bangalore/Singapore
# 1            37.6  Feb-12  Bangalore/Singapore
# 2             1.5  Feb-13    Bangalore/Chicago
# 3             2.4  Oct-14                Delhi
# 4            16.0  Feb-15                Noida
#
#                                     Select Investors
# 0                  KPCB, Sherpalo Ventures, SoftBank
# 1    Accel, Tiger Global, Naspers, SoftBank, Tencent
# 2           Accel, Sequoia Capital, General Atlantic
# ...

# %% [markdown]
# # Lets have a look at top industry from a closer point of view

# %% [markdown]
# # 1. E-Commerce

# %%
Ecommerce = data[data['Sector']== 'E-Commerce']
Ecommerce
# Out:
#     No.      Company      Sector  Entry Valuation^^ ($B)  Valuation ($B)  \
# 1     2    Flipkart^  E-Commerce                     1.0            37.6
# 3     4    Snapdeal*  E-Commerce                     1.8             2.4
# 8     9   ShopClues*  E-Commerce                     1.1             1.1
# 11   12  PayTM Mall*  E-Commerce                     1.9             3.0
#
#      Entry             Location  \
# 1   Feb-12  Bangalore/Singapore
# 3   Oct-14                Delhi
# 8   Jan-16              Gurgaon
# 11  Apr-18                Noida
#
#                                      Select Investors
# 1     Accel, Tiger Global, Naspers, SoftBank, Tencent
# 3   Kalaari Capital, Nexus Ventures, Bessemer, Sof...
# 8   Nexus Ventures, Helion Ventures, Beenos, Tiger...
# 11         Elevation Capital, Alibaba, SoftBank, eBay

# %%
Ecommerce.groupby('Company')['Valuation ($B)'].sum().sort_values(ascending=False).astype(int).reset_index()
# Out:
#        Company  Valuation ($B)
# 0    Flipkart^              37
# 1  PayTM Mall*               3
# 2    Snapdeal*               2
# 3   ShopClues*               1

# %% [markdown]
# # 2. Edtech

# %%
ED_Tech = data[data['Sector']== 'Edtech']
ED_Tech
# Out:
#     No.        Company  Sector  Entry Valuation^^ ($B)  Valuation ($B)  \
# 10   11          BYJUS  Edtech                     1.0            22.0
# 30   31      Unacademy  Edtech                     1.4             3.4
# 65   66        Vedantu  Edtech                     1.0             1.0
# 82   83    LEAD School  Edtech                     1.1             1.1
# 96   97  PhysicsWallah  Edtech                     1.1             1.1
#
#      Entry   Location                                   Select Investors
# 10  Jan-18  Bangalore  Aarin Capital, Sequoia Capital, Lightspeed Ven...
# 30  Sep-20  Bangalore  Blume Ventures, Nexus Venture Partners, Sequoi...
# 65  Sep-21  Bangalore  Accel India, Tiger Global, Omidyar Network, We...
# 82  Jan-22     Mumbai  GSV Ventures, WestBridge, Elevar Equity, TPG G...
# 96  Jun-22      Noida                           GSV Ventures, WestBridge

# %%
ED_Tech.groupby('Company')['Valuation ($B)'].sum().sort_values(ascending=False).astype(int).reset_index()
# Out:
#          Company  Valuation ($B)
# 0          BYJUS              22
# 1      Unacademy               3
# 2    LEAD School               1
# 3  PhysicsWallah               1
# 4        Vedantu               1

# %% [markdown]
# # 3. Logistics

# %%
Logistics = data[data['Sector']=='Logistics Services']
Logistics
# Out:
#     No.               Company              Sector  Entry Valuation^^ ($B)  \
# 18   19            Delhivery^  Logistics Services                     1.6
# 53   54             BlackBuck  Logistics Services                     1.0
# 86   87            ElasticRun  Logistics Services                     1.4
# 88   89  XpressBees Logistics  Logistics Services                     1.2
#
#     Valuation ($B)   Entry   Location  \
# 18             3.0  Jan-19    Gurgaon
# 53             1.0  Jul-21  Bangalore
# 86             1.4  Feb-22       Pune
# 88             1.2  Feb-22       Pune
#
#                                      Select Investors
# 18  Nexus Ventures, Multiples PE, Tiger Global, Ca...
# 53  Accel India, Sequoia Capital India, Sands Capi...
# 86  SoftBank, Goldman Sachs, Prosus Ventures, Kala...
# 88  InvestCorp Group, Norwest, Gaja Capital, TPG G...

# %%
Logistics.groupby('Company')['Valuation ($B)'].sum().sort_values(ascending=False).astype(int).reset_index()
# Out:
#                 Company  Valuation ($B)
# 0            Delhivery^               3
# 1            ElasticRun               1
# 2  XpressBees Logistics               1
# 3             BlackBuck               1

# %% [markdown]
# # Total Valuation by entry year

# %%
total_valuation_per_year = data.groupby('Entry')['Valuation ($B)'].sum()
total_valuation_per_year
# Out:
# Entry
# Apr-15     1.500
# Apr-18     3.000
# Apr-19     8.000
# Apr-21    31.800
# Aug-16     1.400
# Aug-21    14.668
# Aug-22     1.230
# Dec-20    20.500
# Dec-21     3.570
# Feb-12    37.600
# Feb-13     1.500
# Feb-15    16.000
# Feb-19     1.100
# Feb-21     5.700
# Feb-22    17.300
# Jan-16     1.100
# Jan-18    22.000
# Jan-19     3.000
# Jan-20     5.000
# Jan-21     4.000
# Jan-22     4.800
# Jul-18     3.500
# Jul-19    11.100
# Jul-21     7.200
# Jul-22     1.300
# Jun-18    13.100
# Jun-19     2.000
# Jun-20     5.600
# Jun-21     4.000
# Jun-22     3.200
# Mar-15     7.300
# Mar-19     2.000
# Mar-20     1.800
# Mar-21     3.100
# Mar-22     5.800
# May-21     4.100
# May-22     1.000
# Nov-18     1.600
# Nov-20     3.300
# Nov-21    11.100
# Oct-14     2.400
# Oct-20     7.500
# Oct-21     6.900
# Sep-11     1.000
# Sep-15     5.400
# Sep-18    12.700
# Sep-19     4.500
# Sep-20     3.400
# Sep-21     4.400
# Sep-22     1.530
# Name: Valuation ($B), dtype: float64

# %% [markdown]
# # Line chart for total valuation by entry year

# %%
plt.figure(figsize=(20, 6))
total_valuation_per_year.plot(kind='line', marker='o', color='orange')
plt.title('Total Valuation by Entry Year')
plt.xlabel('Entry Year')
plt.ylabel('Total Valuation ($B)')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# # Top 10 investors with the highest number of investments

# %%
top_investors = data['Select Investors'].str.split(',', expand = True).stack().value_counts().head(10)
# Out:
#  Tiger Global             23
#  Sequoia Capital India    16
# Tiger Global              15
#  Steadview Capital        14
#  SoftBank                 13
#  Elevation Capital        10
#  Tencent                   9
#  Norwest                   9
# Sequoia Capital India      9
#  Accel India               8
# dtype: int64

# %% [markdown]
# # Bar chart for top 10 investors with the highest number of investments

# %%
plt.figure(figsize=(20,6))
sns.barplot(top_investors.index,top_investors.values)
plt.title('Top 10 investors with the highest number of investments')
plt.xlabel('Investor')
plt.ylabel('Number of Investments')
plt.xticks(rotation=45)
plt.show()
# Out:
# C:\Users\DELL\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# # Conclusion: Pioneering the Transformation of India's Entrepreneurial Landscape
#
# In the grand tapestry of India's startup journey, the emergence of 101 unicorn startups between 2015 and 2022 stands as a testament to the nation's remarkable strides in innovation, entrepreneurship, and technology. These visionary enterprises, with Edtech leading the way, signify more than financial success – they represent a collective aspiration to redefine industries and contribute to India's economic renaissance.
#
# The analysis of their evolution, from an average entry valuation of 1.4 billion Dollars to an impressive 3.4 billion Dollars, underscores their rapid growth trajectory. These startups, once small seeds of ideas, have burgeoned into influential forces, captivating the attention and investments of renowned backers such as Tiger Global, Sequoia Capital India, and Steadview Capital.
#
# As these unicorns navigate their paths forward, they epitomize innovation, generating employment opportunities, and advancing technology adoption. Their stories interweave with the narrative of India's entrepreneurial spirit, demonstrating resilience, adaptability, and a collective pursuit of excellence.
#
# The journey of these startups, while spanning only a few years, mirrors India's broader journey of transformation. They showcase the nation's prowess to harness its immense potential and transition into an innovation-driven economy. As they continue their voyage, they illuminate a path for aspiring entrepreneurs, catalyzing progress and leaving an indelible mark on India's entrepreneurial canvas.
#
# With each stride they take, these startups not only shape their own destinies but contribute to the larger story of India's growth. Their evolution serves as an inspiration, a lesson, and a testament to the heights that can be reached when ideas are nurtured with determination and innovation is met with support.
#
# As we close this chapter of exploration, the narrative of Indian unicorn startups remains a shining beacon, illuminating the boundless possibilities that lie ahead for the nation's entrepreneurial ecosystem.
#
# The journey has just begun.
# ![Image](Startups.png)
